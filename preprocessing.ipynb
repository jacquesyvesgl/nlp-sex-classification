# %%
import pandas as pd
import re

# %%
def parse_line(line):
    attributes = {}
    pairs = re.findall(r'(\w+): (\S+)', line)
    for key, value in pairs:
        attributes[key] = value
    return attributes

# Function to create DataFrame from input text
def create_dataframe(filename, col="groundtruth"):
    df = pd.read_csv(filename, sep=',')
    data = []

    for _, row in df.iterrows():
        attributes = parse_line(row[col])
        attributes["sex"] = row["sex"]
        data.append(attributes)

    return pd.DataFrame(data)

# Create DataFrame
df_gt = create_dataframe("data_raw.csv")

# %% [markdown]
# ## Parse `groundtruth` column

# %%
df_gt
# Out:
#       surname   firstname occupation        link  age    sex employer  \
# 0     Chardon       Marie       idem       fille   30  femme      NaN
# 1    Lhopital  Louis-Jean         sp        chef   67  homme      NaN
# 2       Papin       Marie       idem        idem   15  femme     idem
# 3     Lavocat       Marie        NaN       femme  NaN  femme      NaN
# 4       Benne  Marguerite        NaN         NaN   78  femme      NaN
# ..        ...         ...        ...         ...  ...    ...      ...
# 236  Burlurut  Pétronille       sans      épouse   61  femme      NaN
# 237    Combey   Alexandre       idem         son   39  homme      NaN
# 238    Collin  Marguerite       idem      épouse   38  femme     idem
# 239    Dumont     Etienne        NaN        fils  NaN  homme      NaN
# 240    Renaut  Antoinette        NaN  belle-mère  NaN  femme      NaN
#
#     birth_date    lob civil_status observation
# 0          NaN    NaN          NaN         NaN
# 1          NaN    NaN          NaN         NaN
# 2          NaN    NaN          NaN         NaN
# 3         1875  Rigny          NaN         NaN
# 4          NaN    NaN          NaN         NaN
# ..         ...    ...          ...         ...
# 236        NaN    NaN          NaN         NaN
# 237        NaN    NaN          NaN         NaN
# 238        NaN    NaN          NaN         NaN
# 239       1900   idem          NaN         NaN
# 240       1849  Rigny          NaN         NaN
#
# [241 rows x 11 columns]

# %%
cols = df_gt.columns.tolist()
cols = cols[:5] + cols[6:] + [cols[5]]
cols
# Out:
# ['surname',
#  'firstname',
#  'occupation',
#  'link',
#  'age',
#  'employer',
#  'birth_date',
#  'lob',
#  'civil_status',
#  'observation',
#  'sex']

# %%
df_gt.to_csv("gt_processed.csv", index=False)

# %%
cols = ['surname',
        'firstname',
        'occupation',
        'link',
        'age',
        'sex']

# %%
df_gt = df_gt[cols]
df_gt
# Out:
#       surname   firstname occupation        link  age    sex
# 0     Chardon       Marie       idem       fille   30  femme
# 1    Lhopital  Louis-Jean         sp        chef   67  homme
# 2       Papin       Marie       idem        idem   15  femme
# 3     Lavocat       Marie        NaN       femme  NaN  femme
# 4       Benne  Marguerite        NaN         NaN   78  femme
# ..        ...         ...        ...         ...  ...    ...
# 236  Burlurut  Pétronille       sans      épouse   61  femme
# 237    Combey   Alexandre       idem         son   39  homme
# 238    Collin  Marguerite       idem      épouse   38  femme
# 239    Dumont     Etienne        NaN        fils  NaN  homme
# 240    Renaut  Antoinette        NaN  belle-mère  NaN  femme
#
# [241 rows x 6 columns]

# %%
# Function to transform text in DataFrame to lowercase
def lowercase_text(df):
    for column in ["surname", "firstname", "occupation", "link"]:
        if df[column].dtype == 'object':  # Check if column contains text
            df[column] = df[column].str.lower()
    return df

# Transform text to lowercase
df_lower_gt = lowercase_text(df_gt)
# Out:
# /tmp/ipykernel_7610/1629643547.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.lower()

# %%
df_lower_gt
# Out:
#       surname   firstname occupation        link  age    sex
# 0     chardon       marie       idem       fille   30  femme
# 1    lhopital  louis-jean         sp        chef   67  homme
# 2       papin       marie       idem        idem   15  femme
# 3     lavocat       marie        NaN       femme  NaN  femme
# 4       benne  marguerite        NaN         NaN   78  femme
# ..        ...         ...        ...         ...  ...    ...
# 236  burlurut  pétronille       sans      épouse   61  femme
# 237    combey   alexandre       idem         son   39  homme
# 238    collin  marguerite       idem      épouse   38  femme
# 239    dumont     etienne        NaN        fils  NaN  homme
# 240    renaut  antoinette        NaN  belle-mère  NaN  femme
#
# [241 rows x 6 columns]

# %%
df_lower_gt.to_csv("data.csv", index=False)

# %% [markdown]
# ## Parse `prediction` column

# %%
df_pred = create_dataframe("transcriptions_with_sex.csv", col="prediction")
df_pred.sample(20)
# Out:
#             nom      prénom date_naissance lieux_naissance     sex  \
# 211       Thély        Jean           1892        Coulange   homme
# 44       Dumont     Etienne           1881        Coulonge   homme
# 178      Vacter  Marguerite             28               P   femme
# 12      Raduron        Anne             53               s   femme
# 202        Dory     Jacques             35               d   homme
# 10       Cofain     Jacques             12               P   homme
# 221     Haureau      Célina           1887          Lasset   femme
# 97        Demay   Joséphine             27            iant   femme
# 167    Bauchard      Joseph           1863            Cher   homme
# 234      Cognet        Ferd             53            sans   homme
# 174     Pojuche        René             01              id   homme
# 75       Vivier      Claude           9013             NaN   homme
# 233       Caute      Barthe              6             ans   homme
# 121   Kaermazet   Branistau           1908         Vipnica   homme
# 140       Baron     Auguste           1804              id   homme
# 148  Villeneuve      Louise             77             NaN   femme
# 50    Pailleret        Paul             60              id   homme
# 207     Leseure     Jacques             55            Savo   homme
# 214       Belin  Marguerite             47               "   femme
# 204           d     Entonie             16               d  ambigu
#
#         employeur  relation   profession état_civil éducation
# 211           NaN        id           id        NaN       NaN
# 44   patron!18371      chef   culviciste        NaN       NaN
# 178           NaN     fomme          NaN          v       NaN
# 12            NaN         p          NaN          s       NaN
# 202           NaN      Chef  eublinateur        NaN       NaN
# 10            NaN       NaN          NaN        NaN       NaN
# 221           NaN  employée          NaN        NaN       NaN
# 97            NaN       NaN          NaN          M       NaN
# 167           NaN      chef       naveur        NaN       NaN
# 234           NaN      chef          NaN        NaN       NaN
# 174           NaN       NaN           id        NaN       NaN
# 75            NaN      bend          NaN        NaN       NaN
# 233           NaN      chef     eublinat        NaN       NaN
# 121        Labrye     frère    manoeuvre        NaN       NaN
# 140           NaN      bent          NaN        NaN       NaN
# 148           NaN  emllisat          NaN        NaN       NaN
# 50         patron       NaN    voiturier        NaN       NaN
# 207           NaN       NaN          NaN        NaN       NaN
# 214        patron       NaN      represt        NaN       NaN
# 204           NaN         f          NaN        NaN       NaN

# %%
cols = df_pred.columns.tolist()
cols = cols[:4] + cols[5:] + [cols[4]]
cols
# Out:
# ['nom',
#  'prénom',
#  'date_naissance',
#  'lieux_naissance',
#  'employeur',
#  'relation',
#  'profession',
#  'état_civil',
#  'éducation',
#  'sex']

# %%
df_pred.to_csv("preds_processed.csv", index=False)

# %%
set(df_pred["éducation"])
# Out:
# {'m', nan}

# %%
set(df_pred["état_civil"])
# Out:
# {"'",
#  "''",
#  'C',
#  'Ch',
#  'Chef',
#  'Cheus)',
#  'D',
#  'M',
#  'S',
#  'V',
#  'Vitant',
#  'id',
#  'm',
#  'marns',
#  'marnt',
#  'me',
#  'meunicien',
#  'mère',
#  nan,
#  's',
#  'sse',
#  'v'}

# %%
for s in set(df_pred["relation"]):
    print(s)
# Out:
# camprof
# ''
# petite
# cuisinière
# C
# nan
# Gonde
# belle
# cultinière
# enfant
# ouvrier
# d°
# noraise
# coiffeur
# Chef
# Par
# Rouher
# bend
# chausne
# domest
# Empl
# a
# id
# io
# Emp
# argentière
# Ch
# fimme
# pard
# f
# D
# bent
# coms
# patissier
# Enfant
# sa
# d
# Ep
# P
# fins
# 'h
# emllisat
# couturière
# noant
# fille
# cullinière
# sans
# femme
# employée
# fils
# B
# par
# epre
# p
# frère
# F
# chef
# ep
# domestique
# ch
# néant
# se
# ép
# "
# patron
# s
# inf
# chemin
# prof
# fomme
# nevur
# éprest
# enf
# Chemin
# chacon

# %%
cols= ['nom',
 'prénom',
 'date_naissance',
 'lieux_naissance',
 'employeur',
 'relation',
 'profession',
 'état_civil',
 'éducation',
 'sex']

# %% [markdown]
# ## Processing `firstname_with_sex`

# %%
firstname_with_sex = pd.read_csv("firstname_with_sex.csv", sep=";")
firstname_with_sex.head()
# Out:
#   firstname     male   female
# 0     marie    10145  2390322
# 1      jean  1869615     6476
# 2    pierre  1475841     5047
# 3    jeanne     1765  1097397
# 4  françois  1089009     5951

# %%
firstname_with_sex["frequency"] = firstname_with_sex["female"] / (firstname_with_sex["female"] + firstname_with_sex["male"])

# %%
firstname_with_sex.to_csv("firstname_with_frequency.csv")
